# %% [markdown]
# ## **Codigo en general**

# %%
import numpy as np

# Función de activación (Función escalón)
def funcion_activacion(x):
    return 1 if x >= 0 else 0

# Inicializar los pesos y el umbral
def inicializar_pesos(n_entradas):
    # Pesos inicializados entre -1 y 1
    pesos = np.random.uniform(-1, 1, n_entradas)
    umbral = np.random.uniform(-1, 1)
    return pesos, umbral

# Propagación hacia adelante
def propagacion(X, pesos, umbral):
    # Calcular y = X·W - θ
    suma = np.dot(X, pesos) - umbral
    return funcion_activacion(suma)

# Entrenamiento del perceptrón
def entrenar_perceptron(X, D, alfa, iteraciones):
    n_entradas = X.shape[1]
    pesos, umbral = inicializar_pesos(n_entradas)

    for _ in range(iteraciones):
        for i in range(len(X)):
            # Paso 1: Propagación
            y = propagacion(X[i], pesos, umbral)

            # Paso 2: Calcular el error
            error = D[i] - y

            # Paso 3: Retropropagación y actualización de pesos y umbral
            pesos += alfa * error * X[i]
            umbral -= alfa * error  # Actualizar umbral

    return pesos, umbral

# Probando el perceptrón
if __name__ == "__main__":
    # Datos de entrenamiento (X) y salidas deseadas (D)
    # Ejemplo simple con 2 entradas y salidas binarias
    X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    D = np.array([0, 0, 0, 1])  # Comportamiento de una puerta lógica AND

    # Parámetros de aprendizaje
    alfa = 0.1  # Tasa de aprendizaje
    iteraciones = 100  # Número de iteraciones

    # Entrenar el perceptrón
    pesos, umbral = entrenar_perceptron(X, D, alfa, iteraciones)

    # Imprimir resultados
    print("Pesos finales:", pesos)
    print("Umbral final:", umbral)

    # Evaluación del perceptrón
    for i in range(len(X)):
        y_pred = propagacion(X[i], pesos, umbral)
        print(f"Entrada: {X[i]}, Predicción: {y_pred}, Esperado: {D[i]}")
# Out:
# Pesos finales: [0.26995338 0.09591932]
# Umbral final: 0.2952041938413342
# Entrada: [0 0], Predicción: 0, Esperado: 0
# Entrada: [0 1], Predicción: 0, Esperado: 0
# Entrada: [1 0], Predicción: 0, Esperado: 0
# Entrada: [1 1], Predicción: 1, Esperado: 1

# %% [markdown]
# Función Escalón

# %%
import numpy as np

def funcion_escalon(x):
    return 1 if x >= 0 else 0

def inicializar_pesos(n_entradas):
    return np.random.uniform(-1, 1, n_entradas), np.random.uniform(-1, 1)

def propagacion(X, pesos, umbral):
    suma = np.dot(X, pesos) - umbral
    return funcion_escalon(suma)

def calcular_error(deseado, y):
    return deseado - y

def actualizar_pesos(pesos, umbral, alfa, error, X):
    return pesos + alfa * error * X, umbral - alfa * error

def entrenar_perceptron(X, D, alfa, iteraciones, umbral_error=0.01):
    pesos, umbral = inicializar_pesos(X.shape[1])
    for epoca in range(iteraciones):
        errores = []
        for i in range(len(X)):
            y = propagacion(X[i], pesos, umbral)
            error = calcular_error(D[i], y)
            errores.append(error ** 2)
            pesos, umbral = actualizar_pesos(pesos, umbral, alfa, error, X[i])
        mse = np.mean(errores)
        print(f"Época {epoca+1}, Error Promedio (MSE): {mse}")
        if mse < umbral_error:
            print("Error aceptable alcanzado.")
            break
    return pesos, umbral

# Datos de prueba
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
D = np.array([0, 0, 0, 1])
alfa = 0.1
iteraciones = 100
pesos, umbral = entrenar_perceptron(X, D, alfa, iteraciones)
# Out:
# Época 1, Error Promedio (MSE): 0.75
# Época 2, Error Promedio (MSE): 0.75
# Época 3, Error Promedio (MSE): 0.75
# Época 4, Error Promedio (MSE): 0.5
# Época 5, Error Promedio (MSE): 0.5
# Época 6, Error Promedio (MSE): 0.5
# Época 7, Error Promedio (MSE): 0.5
# Época 8, Error Promedio (MSE): 0.5
# Época 9, Error Promedio (MSE): 0.25
# Época 10, Error Promedio (MSE): 0.5
# Época 11, Error Promedio (MSE): 0.5
# Época 12, Error Promedio (MSE): 0.25
# Época 13, Error Promedio (MSE): 0.0
# Error aceptable alcanzado.

# %% [markdown]
# Función Sigmoide

# %%
import numpy as np

def funcion_sigmoide(x):
    return 1 / (1 + np.exp(-x))

def inicializar_pesos(n_entradas):
    return np.random.uniform(-1, 1, n_entradas), np.random.uniform(-1, 1)

def propagacion(X, pesos, umbral):
    suma = np.dot(X, pesos) - umbral
    return funcion_sigmoide(suma)

def calcular_error(deseado, y):
    return deseado - y

def actualizar_pesos(pesos, umbral, alfa, error, X):
    return pesos + alfa * error * X, umbral - alfa * error

def entrenar_perceptron(X, D, alfa, iteraciones, umbral_error=0.01):
    pesos, umbral = inicializar_pesos(X.shape[1])
    for epoca in range(iteraciones):
        errores = []
        for i in range(len(X)):
            y = propagacion(X[i], pesos, umbral)
            error = calcular_error(D[i], y)
            errores.append(error ** 2)
            pesos, umbral = actualizar_pesos(pesos, umbral, alfa, error, X[i])
        mse = np.mean(errores)
        print(f"Época {epoca+1}, Error Promedio (MSE): {mse}")
        if mse < umbral_error:
            print("Error aceptable alcanzado.")
            break
    return pesos, umbral

# Datos de prueba
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
D = np.array([0, 0, 0, 1])
alfa = 0.1
iteraciones = 100
pesos, umbral = entrenar_perceptron(X, D, alfa, iteraciones)
# Out:
# Época 1, Error Promedio (MSE): 0.39852914757603036
# Época 2, Error Promedio (MSE): 0.37482363859560636
# Época 3, Error Promedio (MSE): 0.35443439558868695
# Época 4, Error Promedio (MSE): 0.33686165960230546
# Época 5, Error Promedio (MSE): 0.321633304614844
# Época 6, Error Promedio (MSE): 0.30833668532981434
# Época 7, Error Promedio (MSE): 0.29662540448279606
# Época 8, Error Promedio (MSE): 0.28621499590828486
# Época 9, Error Promedio (MSE): 0.27687463065498485
# Época 10, Error Promedio (MSE): 0.2684181552065782
# Época 11, Error Promedio (MSE): 0.26069584656592937
# Época 12, Error Promedio (MSE): 0.2535873470386171
# Época 13, Error Promedio (MSE): 0.2469958267675823
# Época 14, Error Promedio (MSE): 0.24084325479233604
# Época 15, Error Promedio (MSE): 0.2350666082263914
# Época 16, Error Promedio (MSE): 0.2296148490717982
# Época 17, Error Promedio (MSE): 0.22444651789797465
# Época 18, Error Promedio (MSE): 0.21952781860568155
# Época 19, Error Promedio (MSE): 0.21483109254000327
# Época 20, Error Promedio (MSE): 0.21033360102251897
# Época 21, Error Promedio (MSE): 0.20601655245981898
# Época 22, Error Promedio (MSE): 0.20186432382457517
# Época 23, Error Promedio (MSE): 0.19786383702434546
# Época 24, Error Promedio (MSE): 0.19400405903261364
# Época 25, Error Promedio (MSE): 0.190275601158926
# Época 26, Error Promedio (MSE): 0.18667039789766404
# Época 27, Error Promedio (MSE): 0.18318144975002018
# Época 28, Error Promedio (MSE): 0.17980261751871607
# Época 29, Error Promedio (MSE): 0.1765284580268396
# Época 30, Error Promedio (MSE): 0.17335409316012146
# Época 31, Error Promedio (MSE): 0.17027510568879273
# Época 32, Error Promedio (MSE): 0.16728745657611585
# Época 33, Error Promedio (MSE): 0.16438741949046837
# Época 34, Error Promedio (MSE): 0.1615715290559558
# Época 35, Error Promedio (MSE): 0.15883654004104986
# Época 36, Error Promedio (MSE): 0.15617939522541946
# Época 37, Error Promedio (MSE): 0.1535972001253157
# Época 38, Error Promedio (MSE): 0.15108720311621793
# Época 39, Error Promedio (MSE): 0.14864677978289284
# Época 40, Error Promedio (MSE): 0.1462734205636923
# Época 41, Error Promedio (MSE): 0.1439647209477033
# Época 42, Error Promedio (MSE): 0.14171837363837345
# Época 43, Error Promedio (MSE): 0.13953216222214776
# Época 44, Error Promedio (MSE): 0.13740395598095909
# Época 45, Error Promedio (MSE): 0.1353317055676639
# Época 46, Error Promedio (MSE): 0.13331343932744755
# Época 47, Error Promedio (MSE): 0.13134726009892017
# Época 48, Error Promedio (MSE): 0.12943134236863119
# Época 49, Error Promedio (MSE): 0.12756392968411867
# Época 50, Error Promedio (MSE): 0.12574333225508888
# Época 51, Error Promedio (MSE): 0.12396792469127788
# Época 52, Error Promedio (MSE): 0.12223614384011086
# Época 53, Error Promedio (MSE): 0.12054648669836024
# Época 54, Error Promedio (MSE): 0.11889750838035186
# Época 55, Error Promedio (MSE): 0.11728782013147174
# Época 56, Error Promedio (MSE): 0.11571608738026115
# Época 57, Error Promedio (MSE): 0.11418102782563402
# Época 58, Error Promedio (MSE): 0.11268140955801234
# Época 59, Error Promedio (MSE): 0.11121604921468595
# Época 60, Error Promedio (MSE): 0.1097838101706552
# Época 61, Error Promedio (MSE): 0.10838360076675169
# Época 62, Error Promedio (MSE): 0.10701437257706911
# Época 63, Error Promedio (MSE): 0.10567511871775953
# Época 64, Error Promedio (MSE): 0.1043648721991287
# Época 65, Error Promedio (MSE): 0.10308270432274824
# Época 66, Error Promedio (MSE): 0.10182772312502668
# Época 67, Error Promedio (MSE): 0.10059907186838166
# Época 68, Error Promedio (MSE): 0.09939592758084158
# Época 69, Error Promedio (MSE): 0.09821749964460114
# Época 70, Error Promedio (MSE): 0.09706302843376384
# Época 71, Error Promedio (MSE): 0.09593178400123575
# Época 72, Error Promedio (MSE): 0.09482306481449145
# Época 73, Error Promedio (MSE): 0.0937361965397148
# Época 74, Error Promedio (MSE): 0.09267053087362939
# Época 75, Error Promedio (MSE): 0.0916254444221696
# Época 76, Error Promedio (MSE): 0.09060033762500486
# Época 77, Error Promedio (MSE): 0.08959463372481857
# Época 78, Error Promedio (MSE): 0.08860777778014914
# Época 79, Error Promedio (MSE): 0.08763923572052995
# Época 80, Error Promedio (MSE): 0.08668849344261116
# Época 81, Error Promedio (MSE): 0.0857550559459079
# Época 82, Error Promedio (MSE): 0.0848384465067953
# Época 83, Error Promedio (MSE): 0.0839382058893598
# Época 84, Error Promedio (MSE): 0.08305389159171248
# Época 85, Error Promedio (MSE): 0.08218507712638057
# Época 86, Error Promedio (MSE): 0.08133135133340583
# Época 87, Error Promedio (MSE): 0.08049231772480032
# Época 88, Error Promedio (MSE): 0.07966759385903815
# Época 89, Error Promedio (MSE): 0.07885681074428995
# Época 90, Error Promedio (MSE): 0.07805961226914271
# Época 91, Error Promedio (MSE): 0.07727565465958353
# Época 92, Error Promedio (MSE): 0.07650460596106395
# Época 93, Error Promedio (MSE): 0.0757461455445026
# Época 94, Error Promedio (MSE): 0.07499996363512276
# Época 95, Error Promedio (MSE): 0.07426576086306444
# Época 96, Error Promedio (MSE): 0.07354324783475069
# Época 97, Error Promedio (MSE): 0.07283214472402907
# Época 98, Error Promedio (MSE): 0.07213218088215022
# Época 99, Error Promedio (MSE): 0.07144309446568478
# Época 100, Error Promedio (MSE): 0.07076463208151978

# %% [markdown]
# Función Tanh

# %%
import numpy as np

def funcion_tanh(x):
    return np.tanh(x)

def inicializar_pesos(n_entradas):
    return np.random.uniform(-1, 1, n_entradas), np.random.uniform(-1, 1)

def propagacion(X, pesos, umbral):
    suma = np.dot(X, pesos) - umbral
    return funcion_tanh(suma)

def calcular_error(deseado, y):
    return deseado - y

def actualizar_pesos(pesos, umbral, alfa, error, X):
    return pesos + alfa * error * X, umbral - alfa * error

def entrenar_perceptron(X, D, alfa, iteraciones, umbral_error=0.01):
    pesos, umbral = inicializar_pesos(X.shape[1])
    for epoca in range(iteraciones):
        errores = []
        for i in range(len(X)):
            y = propagacion(X[i], pesos, umbral)
            error = calcular_error(D[i], y)
            errores.append(error ** 2)
            pesos, umbral = actualizar_pesos(pesos, umbral, alfa, error, X[i])
        mse = np.mean(errores)
        print(f"Época {epoca+1}, Error Promedio (MSE): {mse}")
        if mse < umbral_error:
            print("Error aceptable alcanzado.")
            break
    return pesos, umbral

# Datos de prueba
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
D = np.array([0, 0, 0, 1])
alfa = 0.1
iteraciones = 100
pesos, umbral = entrenar_perceptron(X, D, alfa, iteraciones)
# Out:
# Época 1, Error Promedio (MSE): 0.1971718114807385
# Época 2, Error Promedio (MSE): 0.1768238074235468
# Época 3, Error Promedio (MSE): 0.16456948632173776
# Época 4, Error Promedio (MSE): 0.1548254942605949
# Época 5, Error Promedio (MSE): 0.14632934202841463
# Época 6, Error Promedio (MSE): 0.13880158993654024
# Época 7, Error Promedio (MSE): 0.1321628657537633
# Época 8, Error Promedio (MSE): 0.12635575757203626
# Época 9, Error Promedio (MSE): 0.1213133447649708
# Época 10, Error Promedio (MSE): 0.11696062342916355
# Época 11, Error Promedio (MSE): 0.11322063645818231
# Época 12, Error Promedio (MSE): 0.11001918735070804
# Época 13, Error Promedio (MSE): 0.10728753151632246
# Época 14, Error Promedio (MSE): 0.10496357222148944
# Época 15, Error Promedio (MSE): 0.10299213227653657
# Época 16, Error Promedio (MSE): 0.1013247107057513
# Época 17, Error Promedio (MSE): 0.09991898188156469
# Época 18, Error Promedio (MSE): 0.0987381888391957
# Época 19, Error Promedio (MSE): 0.09775051594162643
# Época 20, Error Promedio (MSE): 0.0969284861682916
# Época 21, Error Promedio (MSE): 0.09624840505840307
# Época 22, Error Promedio (MSE): 0.09568986011254581
# Época 23, Error Promedio (MSE): 0.09523527713515695
# Época 24, Error Promedio (MSE): 0.09486953112278385
# Época 25, Error Promedio (MSE): 0.09457960741361704
# Época 26, Error Promedio (MSE): 0.09435430805818772
# Época 27, Error Promedio (MSE): 0.0941839982483842
# Época 28, Error Promedio (MSE): 0.09406038785872453
# Época 29, Error Promedio (MSE): 0.09397634353889245
# Época 30, Error Promedio (MSE): 0.09392572725077614
# Época 31, Error Promedio (MSE): 0.09390325761031909
# Época 32, Error Promedio (MSE): 0.09390439084353336
# Época 33, Error Promedio (MSE): 0.0939252185813127
# Época 34, Error Promedio (MSE): 0.09396238009244523
# Época 35, Error Promedio (MSE): 0.09401298688686488
# Época 36, Error Promedio (MSE): 0.09407455791305058
# Época 37, Error Promedio (MSE): 0.09414496382743756
# Época 38, Error Promedio (MSE): 0.09422237903333165
# Época 39, Error Promedio (MSE): 0.09430524037588724
# Época 40, Error Promedio (MSE): 0.09439221154192735
# Época 41, Error Promedio (MSE): 0.09448215235221405
# Época 42, Error Promedio (MSE): 0.09457409225237241
# Época 43, Error Promedio (MSE): 0.09466720740985139
# Época 44, Error Promedio (MSE): 0.09476080091055196
# Época 45, Error Promedio (MSE): 0.09485428562223168
# Época 46, Error Promedio (MSE): 0.09494716935438084
# Época 47, Error Promedio (MSE): 0.09503904199757542
# Época 48, Error Promedio (MSE): 0.09512956437072537
# Época 49, Error Promedio (MSE): 0.09521845854334315
# Época 50, Error Promedio (MSE): 0.09530549943295673
# Época 51, Error Promedio (MSE): 0.09539050750594977
# Época 52, Error Promedio (MSE): 0.09547334243415083
# Época 53, Error Promedio (MSE): 0.09555389758003513
# Época 54, Error Promedio (MSE): 0.09563209520097192
# Época 55, Error Promedio (MSE): 0.09570788227798756
# Época 56, Error Promedio (MSE): 0.09578122688740351
# Época 57, Error Promedio (MSE): 0.0958521150447595
# Época 58, Error Promedio (MSE): 0.09592054795992631
# Época 59, Error Promedio (MSE): 0.09598653965046947
# Época 60, Error Promedio (MSE): 0.09605011486734771
# Época 61, Error Promedio (MSE): 0.0961113072930791
# Época 62, Error Promedio (MSE): 0.09617015797772416
# Época 63, Error Promedio (MSE): 0.09622671398254218
# Época 64, Error Promedio (MSE): 0.09628102720506942
# Época 65, Error Promedio (MSE): 0.09633315336274026
# Época 66, Error Promedio (MSE): 0.09638315111509144
# Época 67, Error Promedio (MSE): 0.09643108130712344
# Época 68, Error Promedio (MSE): 0.09647700631859157
# Época 69, Error Promedio (MSE): 0.0965209895059123
# Época 70, Error Promedio (MSE): 0.0965630947250336
# Época 71, Error Promedio (MSE): 0.09660338592506724
# Época 72, Error Promedio (MSE): 0.09664192680374495
# Época 73, Error Promedio (MSE): 0.09667878051686346
# Época 74, Error Promedio (MSE): 0.09671400943484666
# Época 75, Error Promedio (MSE): 0.09674767494039542
# Época 76, Error Promedio (MSE): 0.09677983726193426
# Época 77, Error Promedio (MSE): 0.09681055533820847
# Época 78, Error Promedio (MSE): 0.0968398867099522
# Época 79, Error Promedio (MSE): 0.09686788743504506
# Época 80, Error Promedio (MSE): 0.09689461202400988
# Época 81, Error Promedio (MSE): 0.0969201133930882
# Época 82, Error Promedio (MSE): 0.09694444283246632
# Época 83, Error Promedio (MSE): 0.09696764998752092
# Época 84, Error Promedio (MSE): 0.09698978285121401
# Época 85, Error Promedio (MSE): 0.09701088776599583
# Época 86, Error Promedio (MSE): 0.09703100943377735
# Época 87, Error Promedio (MSE): 0.0970501909327107
# Época 88, Error Promedio (MSE): 0.097068473739674
# Época 89, Error Promedio (MSE): 0.09708589775749463
# Época 90, Error Promedio (MSE): 0.09710250134606657
# Época 91, Error Promedio (MSE): 0.09711832135662628
# Época 92, Error Promedio (MSE): 0.09713339316854439
# Época 93, Error Promedio (MSE): 0.0971477507280763
# Época 94, Error Promedio (MSE): 0.09716142658858612
# Época 95, Error Promedio (MSE): 0.0971744519518257
# Época 96, Error Promedio (MSE): 0.09718685670990564
# Época 97, Error Promedio (MSE): 0.09719866948764676
# Época 98, Error Promedio (MSE): 0.09720991768504521
# Época 99, Error Promedio (MSE): 0.09722062751962224
# Época 100, Error Promedio (MSE): 0.09723082406846477

# %% [markdown]
# Función ReLU

# %%
import numpy as np

def funcion_relu(x):
    return max(0, x)

def inicializar_pesos(n_entradas):
    return np.random.uniform(-1, 1, n_entradas), np.random.uniform(-1, 1)

def propagacion(X, pesos, umbral):
    suma = np.dot(X, pesos) - umbral
    return funcion_relu(suma)

def calcular_error(deseado, y):
    return deseado - y

def actualizar_pesos(pesos, umbral, alfa, error, X):
    return pesos + alfa * error * X, umbral - alfa * error

def entrenar_perceptron(X, D, alfa, iteraciones, umbral_error=0.01):
    pesos, umbral = inicializar_pesos(X.shape[1])
    for epoca in range(iteraciones):
        errores = []
        for i in range(len(X)):
            y = propagacion(X[i], pesos, umbral)
            error = calcular_error(D[i], y)
            errores.append(error ** 2)
            pesos, umbral = actualizar_pesos(pesos, umbral, alfa, error, X[i])
        mse = np.mean(errores)
        print(f"Época {epoca+1}, Error Promedio (MSE): {mse}")
        if mse < umbral_error:
            print("Error aceptable alcanzado.")
            break
    return pesos, umbral

# Datos de prueba
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
D = np.array([0, 0, 0, 1])
alfa = 0.1
iteraciones = 100
pesos, umbral = entrenar_perceptron(X, D, alfa, iteraciones)
# Out:
# Época 1, Error Promedio (MSE): 0.6811646938762049
# Época 2, Error Promedio (MSE): 0.5621668640643163
# Época 3, Error Promedio (MSE): 0.48156436039043793
# Época 4, Error Promedio (MSE): 0.4197449740883985
# Época 5, Error Promedio (MSE): 0.369039219664099
# Época 6, Error Promedio (MSE): 0.3260301868390561
# Época 7, Error Promedio (MSE): 0.2889290124795113
# Época 8, Error Promedio (MSE): 0.25663609936142207
# Época 9, Error Promedio (MSE): 0.22870779661870735
# Época 10, Error Promedio (MSE): 0.2052921042778061
# Época 11, Error Promedio (MSE): 0.18555479258011132
# Época 12, Error Promedio (MSE): 0.16893474485957727
# Época 13, Error Promedio (MSE): 0.1549417607370957
# Época 14, Error Promedio (MSE): 0.14315426301413148
# Época 15, Error Promedio (MSE): 0.13321504400082107
# Época 16, Error Promedio (MSE): 0.1248242216079961
# Época 17, Error Promedio (MSE): 0.11773125958096976
# Época 18, Error Promedio (MSE): 0.11152768258520329
# Época 19, Error Promedio (MSE): 0.10584552028514946
# Época 20, Error Promedio (MSE): 0.10061631182930203
# Época 21, Error Promedio (MSE): 0.0957889205281598
# Época 22, Error Promedio (MSE): 0.09131578735186843
# Época 23, Error Promedio (MSE): 0.08715460188230792
# Época 24, Error Promedio (MSE): 0.0832687160952307
# Época 25, Error Promedio (MSE): 0.07962684578321913
# Época 26, Error Promedio (MSE): 0.07620246760679826
# Época 27, Error Promedio (MSE): 0.07297313834762018
# Época 28, Error Promedio (MSE): 0.06991984437582119
# Época 29, Error Promedio (MSE): 0.06702642458142802
# Época 30, Error Promedio (MSE): 0.06427907786524237
# Época 31, Error Promedio (MSE): 0.061665951699335426
# Época 32, Error Promedio (MSE): 0.05917680256125181
# Época 33, Error Promedio (MSE): 0.056802717589729206
# Época 34, Error Promedio (MSE): 0.05453588724477475
# Época 35, Error Promedio (MSE): 0.0523694199216618
# Época 36, Error Promedio (MSE): 0.050297190819879586
# Época 37, Error Promedio (MSE): 0.04831371866303301
# Época 38, Error Promedio (MSE): 0.0464140650114992
# Época 39, Error Promedio (MSE): 0.044593751883262166
# Época 40, Error Promedio (MSE): 0.04284869420727145
# Época 41, Error Promedio (MSE): 0.041175144297065265
# Época 42, Error Promedio (MSE): 0.03956964607226102
# Época 43, Error Promedio (MSE): 0.038028997192844305
# Época 44, Error Promedio (MSE): 0.03655021762450342
# Época 45, Error Promedio (MSE): 0.0351305234382674
# Época 46, Error Promedio (MSE): 0.03376730487744202
# Época 47, Error Promedio (MSE): 0.032458107909961155
# Época 48, Error Promedio (MSE): 0.031200618633449674
# Época 49, Error Promedio (MSE): 0.029992650020532117
# Época 50, Error Promedio (MSE): 0.02883213058887423
# Época 51, Error Promedio (MSE): 0.027717094658655336
# Época 52, Error Promedio (MSE): 0.026645673923303467
# Época 53, Error Promedio (MSE): 0.025616090110322294
# Época 54, Error Promedio (MSE): 0.024626648550261192
# Época 55, Error Promedio (MSE): 0.0236757325052335
# Época 56, Error Promedio (MSE): 0.022761798135396305
# Época 57, Error Promedio (MSE): 0.021883370003698527
# Época 58, Error Promedio (MSE): 0.021039037036972956
# Época 59, Error Promedio (MSE): 0.020227448875882126
# Época 60, Error Promedio (MSE): 0.019447312557973502
# Época 61, Error Promedio (MSE): 0.018697389487667734
# Época 62, Error Promedio (MSE): 0.01797649265480989
# Época 63, Error Promedio (MSE): 0.017283484069796164
# Época 64, Error Promedio (MSE): 0.01661727238851149
# Época 65, Error Promedio (MSE): 0.015976810704600997
# Época 66, Error Promedio (MSE): 0.015361094490120294
# Época 67, Error Promedio (MSE): 0.01476915966851296
# Época 68, Error Promedio (MSE): 0.014200080806261376
# Época 69, Error Promedio (MSE): 0.013652969411540768
# Época 70, Error Promedio (MSE): 0.01312697232985571
# Época 71, Error Promedio (MSE): 0.01262127022800963
# Época 72, Error Promedio (MSE): 0.012135076158903968
# Época 73, Error Promedio (MSE): 0.011667634200624392
# Época 74, Error Promedio (MSE): 0.011218218164078895
# Época 75, Error Promedio (MSE): 0.010786130364133053
# Época 76, Error Promedio (MSE): 0.010370700449766679
# Época 77, Error Promedio (MSE): 0.009971284289264751
# Error aceptable alcanzado.
